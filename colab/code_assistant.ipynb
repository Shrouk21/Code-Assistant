# %% [markdown]
# # 🤖 Smart Code Assistant on Colab

# %% [markdown]
# ## Download Dependencies

# %%
# Cell 2: Install required packages
# !pip install -r !python /content/Code-Assitant/requirements.txt

# %% [markdown]
# ## Activate Ollama

# %%
#   Installing ollama
# !curl -fsSL https://ollama.ai/install.sh | sh

# %%
# Run this in a separate cell
import subprocess
import time
import threading

# Start Ollama in background
def start_ollama():
    subprocess.run(["/usr/local/bin/ollama", "serve"], check=False)

# Start Ollama service in background thread
threading.Thread(target=start_ollama, daemon=True).start()
time.sleep(5)  # Wait for service to start
print("Ollama service started!")
# Out:
# Ollama service started!

# %%
# Run this in a new cell
# !/usr/local/bin/ollama pull codellama:7b

# %% [markdown]
# ## Clone Repo

# %%
import sys

repo_url = 'https://github.com/Shrouk21/Code-Assitant.git'
# !git clone {repo_url}
sys.path.append('/content/Code-Assitant')

# %% [markdown]
# ## Run Script

# %%
# !python /content/Code-Assitant/app.py
